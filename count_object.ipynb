# %% [markdown]
# <a href="https://colab.research.google.com/github/Bahrombekk/Practise/blob/main/count_object.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# %%
def show(img,s=8,b=False):
  plt.figure(figsize=(s,s))
  plt.imshow(img,cmap='gray')
  plt.grid(alpha=.2)
  plt.grid(b)
  plt.show()

# %%
# !wget https://www.dropbox.com/scl/fi/8975rz0yid2rblrad1w0o/photo_2023-09-16_14-29-19.jpg?rlkey=se367vfxvp8wfgdjzf8xb73dr&dl=0
# Out:
# --2023-09-16 17:10:13--  https://www.dropbox.com/scl/fi/8975rz0yid2rblrad1w0o/photo_2023-09-16_14-29-19.jpg?rlkey=se367vfxvp8wfgdjzf8xb73dr
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/e/scl/fi/8975rz0yid2rblrad1w0o/photo_2023-09-16_14-29-19.jpg?rlkey=se367vfxvp8wfgdjzf8xb73dr [following]
# --2023-09-16 17:10:13--  https://www.dropbox.com/e/scl/fi/8975rz0yid2rblrad1w0o/photo_2023-09-16_14-29-19.jpg?rlkey=se367vfxvp8wfgdjzf8xb73dr
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !wget https://www.dropbox.com/scl/fi/zx4ugr3bsvco9qjp03pwv/photo_2023-09-16_22-56-27.jpg?rlkey=15bd4rzwb1lhchhlupt2os39i&dl=0
# Out:
# --2023-09-16 18:02:55--  https://www.dropbox.com/scl/fi/zx4ugr3bsvco9qjp03pwv/photo_2023-09-16_22-56-27.jpg?rlkey=15bd4rzwb1lhchhlupt2os39i
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.64.18, 2620:100:601c:18::a27d:612
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.64.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://www.dropbox.com/e/scl/fi/zx4ugr3bsvco9qjp03pwv/photo_2023-09-16_22-56-27.jpg?rlkey=15bd4rzwb1lhchhlupt2os39i [following]
# --2023-09-16 18:02:56--  https://www.dropbox.com/e/scl/fi/zx4ugr3bsvco9qjp03pwv/photo_2023-09-16_22-56-27.jpg?rlkey=15bd4rzwb1lhchhlupt2os39i
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
image = cv2.imread('/content/photo_2023-09-16_14-29-19.jpg?rlkey=se367vfxvp8wfgdjzf8xb73dr')
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
thresh_img = cv2.inRange(gray,190,255,cv2.THRESH_BINARY_INV)
contours, hierarchy = cv2.findContours(thresh_img, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
cv2_imshow(thresh_img)
print("Number of Contours found =", len(contours))
cv2.drawContours(image, contours, -1, (0, 255, 0), 3)

cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=L size=774x808>
# Number of Contours found = 11
# <PIL.Image.Image image mode=RGB size=774x808>
